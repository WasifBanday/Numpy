# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv("matches.csv")
ipl.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
subjects = ["English", "Mathematics", "Science", "Computer Science", "Hindi"]
marks = [66 , 77 , 82 , 99 , 58]
pd.Series(subjects)
pd.Series(marks)

pd.Series(marks, index=subjects, name="students data")
# Out:
# English             66
# Mathematics         77
# Science             82
# Computer Science    99
# Hindi               58
# Name: students data, dtype: int64

# %%
# marks.mean()

# %%
ipl.sample(5)
# Out:
#           id season       city        date match_type player_of_match  \
# 223   501247   2011  Bangalore  2011-05-08     League        CH Gayle
# 591  1082605   2017      Delhi  2017-04-15     League     CJ Anderson
# 64    392188   2009  Cape Town  2009-04-22     League    AC Gilchrist
# 817  1254059   2021     Mumbai  2021-04-10     League        S Dhawan
# 666  1136591   2018  Bengaluru  2018-05-01     League      TG Southee
#
#                         venue                        team1  \
# 223     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 591          Feroz Shah Kotla             Delhi Daredevils
# 64                   Newlands  Royal Challengers Bangalore
# 817  Wankhede Stadium, Mumbai          Chennai Super Kings
# 666     M.Chinnaswamy Stadium  Royal Challengers Bangalore
#
#                     team2           toss_winner toss_decision  \
# 223  Kochi Tuskers Kerala  Kochi Tuskers Kerala           bat
# ...

# %%
ipl.value_counts()
# Out:
# id       season   city           date        match_type  player_of_match   venue                                                             team1                        team2                        toss_winner                  toss_decision  winner                       result   result_margin  target_runs  target_overs  super_over  method  umpire1                umpire2
# 336022   2007/08  Delhi          2008-05-17  League      DPMD Jayawardene  Feroz Shah Kotla                                                  Delhi Daredevils             Kings XI Punjab              Delhi Daredevils             bat            Kings XI Punjab              runs     6.0            89.0         8.0           N           D/L     AV Jayaprakash         RE Koertzen        1
# ...

# %%
ipl.count()
# Out:
# id                 1095
# season             1095
# city               1044
# date               1095
# match_type         1095
# player_of_match    1090
# venue              1095
# team1              1095
# team2              1095
# toss_winner        1095
# toss_decision      1095
# winner             1090
# result             1095
# result_margin      1076
# target_runs        1092
# target_overs       1092
# super_over         1095
# method               21
# umpire1            1095
# umpire2            1095
# dtype: int64

# %%
mean = np.arange(24, 200)
mean.mean()
mean.max()
mean.std()
# Out:
# 50.806003582253936

# %%
ipl.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
# ipl(["player_of_the_match"])

# %%
import pandas as pd

data = [
    [56 , 87 , 98],
    [36 , 92 , 77],
    [64 , 82 , 44],
]
pd.DataFrame(data  , columns=["IQ", "MARKS", "PACKAGE"])
# Out:
#    IQ  MARKS  PACKAGE
# 0  56     87       98
# 1  36     92       77
# 2  64     82       44

# %%
ipl.shape
ipl.head()
ipl.columns
ipl.values
ipl.isnull()
# Out:
#          id  season   city   date  match_type  player_of_match  venue  team1  \
# 0     False   False  False  False       False            False  False  False
# 1     False   False  False  False       False            False  False  False
# 2     False   False  False  False       False            False  False  False
# 3     False   False  False  False       False            False  False  False
# 4     False   False  False  False       False            False  False  False
# ...     ...     ...    ...    ...         ...              ...    ...    ...
# 1090  False   False  False  False       False            False  False  False
# 1091  False   False  False  False       False            False  False  False
# 1092  False   False  False  False       False            False  False  False
# 1093  False   False  False  False       False            False  False  False
# 1094  False   False  False  False       False            False  False  False
#
# ...

# %%
ipl.duplicated().sum()

# ipl["season", "city"]
ipl.iloc[:, 5]
# ipl.iloc[0:5]
# Out:
# 0           BB McCullum
# 1            MEK Hussey
# 2           MF Maharoof
# 3            MV Boucher
# 4             DJ Hussey
#              ...
# 1090    Abhishek Sharma
# 1091           MA Starc
# 1092           R Ashwin
# 1093      Shahbaz Ahmed
# 1094           MA Starc
# Name: player_of_match, Length: 1095, dtype: object

# %%
# ipl.iloc(0, :, 5)
ipl.iloc[0:5]
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
ipl.loc[0:2]
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
# 2       Rajasthan Royals             Rajasthan Royals           bat
#
#                   winner   result  result_margin  target_runs  target_overs  \
# ...

# %%
ipl.iloc[0:6 , 0:4]
ipl.loc[0:11, 'season' : 'winner']
# Out:
#      season        city        date match_type player_of_match  \
# 0   2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1   2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2   2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3   2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4   2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5   2007/08      Jaipur  2008-04-21     League       SR Watson
# 6   2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7   2007/08     Chennai  2008-04-23     League       ML Hayden
# 8   2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9   2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
# 10  2007/08   Bangalore  2008-04-26     League       SR Watson
# 11  2007/08     Chennai  2008-04-26     League        JDP Oram
#
#                                          venue                        team1  \
# ...

# %%
# mask = ipl['MatchNumber'] == 'Final'
ipl.sample(5)
# Out:
#           id season        city        date match_type player_of_match  \
# 221   501245   2011     Kolkata  2011-05-07     League   Iqbal Abdulla
# 654  1136579   2018   Bengaluru  2018-04-21     League  AB de Villiers
# 199   501223   2011       Delhi  2011-04-23     League       DA Warner
# 950  1359475   2023   Ahmedabad  2023-03-31     League     Rashid Khan
# 224   501248   2011  Chandigarh  2011-05-08     League        R Sharma
#
#                                           venue                  team1  \
# 221                                Eden Gardens  Kolkata Knight Riders
# 654                       M.Chinnaswamy Stadium       Delhi Daredevils
# 199                            Feroz Shah Kotla       Delhi Daredevils
# 950            Narendra Modi Stadium, Ahmedabad    Chennai Super Kings
# 224  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ipl[ipl['super_over'] == 'Y'].shape[0]
# Out:
# 14

# %%
ipl[ipl['winner'] == 'Kolkata Knight Riders'].shape[0]
ipl[ipl['city'] == 'Bengaluru'].shape[0]

ipl[(ipl['city'] == 'kolkata') & (ipl['winner'] == 'Chennai Super Kings')].shape[0]
ipl[ipl['toss_winner'] == 'Royal Challengers Bangalore'].shape[0]
ipl[ipl['super_over'] == 'Y'].shape[0]

ipl[ipl['target_runs'] <= 50]
# Out:
#           id season       city        date  match_type  player_of_match  \
# 429   733993   2014      Delhi  2014-05-10      League         DW Steyn
# 633  1082648   2017  Bangalore  2017-05-17  Eliminator  NM Coulter-Nile
#
#                      venue                team1                  team2  \
# 429       Feroz Shah Kotla     Delhi Daredevils    Sunrisers Hyderabad
# 633  M Chinnaswamy Stadium  Sunrisers Hyderabad  Kolkata Knight Riders
#
#                toss_winner toss_decision                 winner   result  \
# 429    Sunrisers Hyderabad         field    Sunrisers Hyderabad  wickets
# 633  Kolkata Knight Riders         field  Kolkata Knight Riders  wickets
#
#      result_margin  target_runs  target_overs super_over method       umpire1  \
# 429            8.0         43.0           5.0          N    D/L  RM Deshpande
# 633            7.0         48.0           6.0          N    D/L  AK Chaudhary
#
#           umpire2
# 429  BNJ Oxenford
# 633   Nitin Menon

# %%
ipl[ipl['target_runs'].between(260 , 300)]
# Out:
#            id season           city        date match_type  player_of_match  \
# 352    598027   2013      Bangalore  2013-04-23     League         CH Gayle
# 1031  1422126   2024      Hyderabad  2024-03-27     League  Abhishek Sharma
# 1039  1422134   2024  Visakhapatnam  2024-04-03     League        SP Narine
# 1053  1426268   2024      Bengaluru  2024-04-15     League          TM Head
# 1058  1426273   2024          Delhi  2024-04-20     League          TM Head
# 1065  1426280   2024        Kolkata  2024-04-26     League      JM Bairstow
#
#                                                   venue  \
# 352                               M Chinnaswamy Stadium
# 1031  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1039  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 1053                   M Chinnaswamy Stadium, Bengaluru
# 1058                        Arun Jaitley Stadium, Delhi
# 1065                              Eden Gardens, Kolkata
#
# ...

# %%
# ipl['winner'].upper()
