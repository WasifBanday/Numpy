# %%
import numpy as np

# %% [markdown]
#                                       Numpy Array    v/s       Python List
#
#                                       Why Numpy arrray is better then python list

# %%
# Time duration
# python list
a=[i for i in range(10000000)]
b=[i for i in range(10000000,20000000)]
c=[]

import time
start=time.time()

for i in range(len(a)):
    c.append(a[i]+b[i])
print(time.time()-start)


# Numpy Array
a=np.arange(10000000)
b=np.arange(10000000,20000000)
start=time.time()
c=a+b
print(time.time()-start)
# Out:
# 1.8632731437683105
# 0.17620325088500977

# %%
# Memory 
# python
a=[i for i in range(10000000)]
import sys
print(sys.getsizeof(a))

# Numpy
a=np.arange(10000000,dtype=np.int32)
print(sys.getsizeof(a))
# Out:
# 81528056
# 40000104
